# %%
import pandas as pd
from rdkit import Chem
import matplotlib.pyplot as plt
from rdkit.Chem import AllChem
import tqdm

# %%
df = pd.read_csv('./41586_2019_917_MOESM4_ESM.csv').iloc[:-4]
df.head()
# Out:
#             ZINC ID  Global Rank∗  Clustered Rank†  Energy  TC to knowns‡  \
# 0  ZINC000191583186             1                1  -75.50           0.30
# 1  ZINC000159533726             2                2  -73.67           0.33
# 2  ZINC000151228439             3                4  -73.47           0.34
# 3  ZINC000291023493             5                5  -72.95           0.31
# 4  ZINC000593577820             7                7  -72.50           0.35
#
#   Cosest neighbor among known DRD4 binders Top-pick or not  \
# 0                         ZINC000028347504               0
# 1                         ZINC000103232405               0
# 2                         ZINC000053274848               0
# 3                         ZINC000028363497               0
# 4                         ZINC000036216606               0
#
#   Just from energy window Energy window Tested or not Binder or not  \
# 0                       1           -75             1             1
# ...

# %%
dock_energy = df['Energy'].astype(float).values
inhibition = df['Inhibition (%) at 10uM'].astype(float).values
smiles = df['SMILES']
names = df['ZINC ID']

# %%
mols = [Chem.MolFromSmiles(i) for i in smiles]

# %%
with Chem.SDWriter('./mols.sdf') as writer:
    for m, n in tqdm.tqdm_notebook(zip(mols, names), total=len(mols)):
        mH = Chem.AddHs(m)
        AllChem.EmbedMolecule(mH)
        mH.SetProp('_Name', n)
        writer.write(mH)
# Out:
# /var/folders/jh/02165y2n7kq2y5ychxtzcjm40000gn/T/ipykernel_55970/209296595.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for m, n in tqdm.tqdm_notebook(zip(mols, names), total=len(mols)):
#   0%|          | 0/549 [00:00<?, ?it/s]

# %% [markdown]
# # At this stage, dock all the compounds
# i.e. run docking with
# ```
# smina - protein_5WIU.pdbqt -l mols.sdf --autobox_ligand ligand_5WIU.pdb -o docked.sdf
# ```
